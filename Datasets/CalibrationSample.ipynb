# %%
import pandas as pd

df = pd.read_parquet("/content/drive/MyDrive/FYP/Datasets/parquet/test-00000-of-00001.parquet")
output_path = "/content/drive/MyDrive/FYP/Datasets/wikitext/train_500.txt"
# Keep only text column
texts = df["text"].tolist()

# Save first 500 samples
with open(output_path, "w", encoding="utf-8") as f:
    for line in texts[:500]:
        f.write(line.strip() + "\n")
